# %%
metn="PythonProqramlasdirma"
reqemler="01234567890"
cumle="Salam Dunya 2026"

# %%
print(metn[0])
# Out:
# P

# %%
print(metn[6])
# Out:
# P

# %%
print(metn[-1])
# Out:
# a

# %%
print(metn[-2])
# Out:
# m

# %%
print(cumle[5])

# %%
print(cumle[-1])
# Out:
# 6

# %%
print(metn[len(metn)-1])
# Out:
# a

# %%
print(metn[-len (metn)])
# Out:
# P

# %%
indexs=4
print(metn[indexs])
# Out:
# o

# %%
print(metn[2+3])
# Out:
# n

# %%
print(metn[0:6])
# Out:
# Python

# %%
print(metn[:6])
# Out:
# Python

# %%
print(metn[6:])
# Out:
# Proqramlasdirma

# %%
print(metn[6:13])
# Out:
# Proqram

# %%
print(metn[13:19])
# Out:
# lasdir

# %%
print(metn[-5])
# Out:
# d

# %%
print(metn[6:-5])
# Out:
# Proqramlas

# %%
print(metn[10:16])
# Out:
# ramlas

# %%
print(metn[:])
# Out:
# PythonProqramlasdirma

# %%
print(cumle[6:11])
# Out:
# Dunya

# %%
print(cumle[-4:])
# Out:
# 2026

# %%
print(metn[6:100])
# Out:
# Proqramlasdirma

# %%
print(metn[10:5])

# %%
print(metn[5:5])

# %%
print(reqemler[::2])
# Out:
# 024680

# %%
print(reqemler[::3])
# Out:
# 0369

# %%
print(reqemler[2:8:2])
# Out:
# 246

# %%
print(reqemler[:7:3])
# Out:
# 036

# %%
print(reqemler[4::2])
# Out:
# 4680

# %%
print(reqemler[::-1])
# Out:
# 09876543210

# %%
name="salam"

# %%
print(name[::-1])
# Out:
# malas

# %%
print(reqemler[:3:-1])
# Out:
# 0987654

# %%
print(reqemler[5::-1])
# Out:
# 543210

# %%
yeni_metn=metn[:6]
print(yeni_metn)
# Out:
# Python

# %%
kelime="radar"
is_polindrom=kelime==kelime[::-1]
print(is_polindrom)
# Out:
# True

# %%
print(metn[6:13].upper())
# Out:
# PROQRAM

# %%
print(metn[:6] + " " + metn[6:13])
# Out:
# Python Proqram

# %%
print(reqemler[:3] + reqemler[-3:])
# Out:
# 012890

# %%
print(metn[0] + metn[-1])
# Out:
# Pa

# %%
print(len(metn[6:13]))
# Out:
# 7

# %%
yarisi = len(metn) // 2
print(metn[yarisi:])
# Out:
# ramlasdirma

# %%
print(f"Kursun adi:{metn[:6]}")
# Out:
# Kursun adi:Python

# %%
print(cumle[::-1])
