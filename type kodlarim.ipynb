# %% [markdown]
# # INTeger type

# %%
age=5

# %%
type(age)
# Out:
# int

# %%
float(age)
# Out:
# 5.0

# %%
str(age)
# Out:
# '5'

# %% [raw]
# print(age)

# %%
list(age)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 list(age)
#
# TypeError: 'int' object is not iterable

# %%
bool(age)

# %%
tuple(age)

# %%
dict(age)

# %% [markdown]
# ## Float type

# %%
age1=3.5

# %%
int(age1)
# Out:
# 3

# %%
str(age1)
# Out:
# '3.5'

# %%
bool(age1)
# Out:
# True

# %%
list(age1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 list(age1)
#
# TypeError: 'float' object is not iterable

# %%
tuple(age1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 tuple(age1)
#
# TypeError: 'float' object is not iterable

# %%
age2="Hello Word"

# %%
age2
# Out:
# 'Hello Word'

# %%
print(age2)
# Out:
# Hello Word

# %%
int(age2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 int(age2)
#
# ValueError: invalid literal for int() with base 10: 'Hello Word'

# %%
float(age2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 float(age2)
#
# ValueError: could not convert string to float: 'Hello Word'

# %% [markdown]
# ## LIST TYPE

# %%
list(age2)
# Out:
# ['H', 'e', 'l', 'l', 'o', ' ', 'W', 'o', 'r', 'd']

# %%
age3=" Salam Dunya "

# %%
age3
# Out:
# ' Salam Dunya '

# %%
list(age3)
# Out:
# [' ', 'S', 'a', 'l', 'a', 'm', ' ', 'D', 'u', 'n', 'y', 'a', ' ']

# %%
tuple(age3)
# Out:
# (' ', 'S', 'a', 'l', 'a', 'm', ' ', 'D', 'u', 'n', 'y', 'a', ' ')

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 capitalize(age3)
#
# NameError: name 'capitalize' is not defined

# %% [markdown]
# ### List tipinde cevrilmeler

# %%
age4=[2,3,4,5,6,7]

# %%
age4
# Out:
# [2, 3, 4, 5, 6, 7]

# %%
int(age4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 int(age4)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'list'

# %%
str(age4)
# Out:
# '[2, 3, 4, 5, 6, 7]'

# %%
float(age4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 float(age4)
#
# TypeError: float() argument must be a string or a real number, not 'list'

# %%
tuple(age4)
# Out:
# (2, 3, 4, 5, 6, 7)

# %%
bool(age4)
# Out:
# True

# %%
age4=0

# %%
bool(age4)
# Out:
# False

# %%
age4=(0)

# %%
bool(age4)
# Out:
# False

# %% [markdown]
# # Tuple type

# %%
age5=("salam")

# %%
age5
# Out:
# 'salam'

# %%
list(age5)
# Out:
# ['s', 'a', 'l', 'a', 'm']

# %%
str(age5)
# Out:
# 'salam'

# %%
age6="Necesen"

# %%
bool(age5)
# Out:
# True

# %% [markdown]
# ## str type

# %%
name="Hollandiya"

# %%
name2="Vasinqton"

# %%
print( name + "  " + name2 )
# Out:
# Hollandiya  Vasinqton

# %%
print(name2 * 4)
# Out:
# VasinqtonVasinqtonVasinqtonVasinqton

# %%
list(name2)
# Out:
# ['V', 'a', 's', 'i', 'n', 'q', 't', 'o', 'n']

# %%
tuple(name2)
# Out:
# ('V', 'a', 's', 'i', 'n', 'q', 't', 'o', 'n')
