# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
age=5
age1=10
age>age1
# Out:
# False

# %%
age==age1
# Out:
# False

# %%
age<age1
# Out:
# True

# %%
age
# Out:
# 5

# %%
age1
# Out:
# 10

# %%
name="salam"

# %%
name
# Out:
# 'salam'

# %%
print(name)
# Out:
# salam

# %%
age!=age1
# Out:
# True
