# %%
a=4
b=6
c=a+b

# %%
print(c)
# Out:
# 10

# %%
c=a*b
print(c)
# Out:
# 24

# %%
bool(c)
# Out:
# True

# %%
type(c)
# Out:
# int

# %%
age_limit=10
print(type(age_limit))
# Out:
# <class 'int'>

# %%
input_score=95
final_score=int(input_score)
print(final_score+5)
# Out:
# 100

# %%
is_activ=True
status_code=int(is_activ)
print(status_code)
# Out:
# 1

# %%
base_number=5
exponent_value=3
result_power=base_number**exponent_value
print(result_power)
# Out:
# 125

# %%
total_second=450
minutes_count=total_second//60
print(minutes_count)
# Out:
# 7

# %%
total_items=23
box_capacity=5
remaining_items=total_items % box_capacity
print(remaining_items)
# Out:
# 3

# %%
age=2
age1=12.4
age+age1
# Out:
# 14.4

# %%
age_2="salam"
age*age_2
# Out:
# 'salamsalam'

# %%
age_3=[1,2,3]
age_3*age
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
age*age1
# Out:
# 24.8

# %%
age1-age
# Out:
# 10.4

# %%
2**3
# Out:
# 8

# %%
11%2
# Out:
# 1

# %%
0.5*3
# Out:
# 1.5

# %%
1.5*2.5
# Out:
# 3.75

# %%
ag

# %%
player_score=10
player_score+=5
print(player_score)
# Out:
# 15

# %%
base_val=4
power_val=3
mod_val=5
math_result=pow(base_val,power_val,mod_val)
print(math_result)
# Out:
# 4

# %%
age5=13.3
str(age5)
# Out:
# '13.3'

# %% [markdown]
# bool(age5)

# %%
bool(age5)
# Out:
# True

# %%
int(age5)
# Out:
# 13

# %%
age6=13.2
# Out:
# 683662345683379.0
